# %% [markdown]
# <a href="https://colab.research.google.com/github/brian572xd/mineriaDatos/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Mineria de Datos

# %% [markdown]
# ##Primer parcial

# %% [markdown]
# ###Introduccion

# %% [markdown]
# ####Conceptos

# %% [markdown]
# ####Ciencia de datos
